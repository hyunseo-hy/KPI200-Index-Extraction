# %% [markdown]
# <a href="https://colab.research.google.com/github/hyunseo-hy/FinEng/blob/main/Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_dict = {}
storage = []

for i in range(3):
    my_dict['id'] = i
    storage.append(my_dict)
    print(f"{i}번째 저장된 딕셔너리의 주소: {id(my_dict)}")
# Out:
# 0번째 저장된 딕셔너리의 주소: 135805631984256
# 1번째 저장된 딕셔너리의 주소: 135805631984256
# 2번째 저장된 딕셔너리의 주소: 135805631984256
#
# === 최종 결과 ===
# [{'id': 2}, {'id': 2}, {'id': 2}]
